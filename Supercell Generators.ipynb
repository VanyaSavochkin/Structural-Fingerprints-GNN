# %%
#Supercell generator: C2db

import os
from ase.io import write
from ase.db import connect
from ase.build import make_supercell
import numpy as np

# Define the transformation matrix for the supercell expansion
# For example, 2x2 replication in the a and b directions (2D plane)
transformation_matrix = np.array([[SUPERCELL_SIZE, 0, 0],
                                  [0, SUPERCELL_SIZE, 0],
                                  [0, 0, 1]])  # No replication in the c-direction

# Create a folder for saving the supercell files
output_folder = 'Supercells/supercells_c2db'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Connect to the C2DB database (assuming it's in the current directory)
db = connect('Materials/c2db.db')

# Iterate over the structures in the database
for row in db.select():
    # Read the structure (unit cell) from the database
    unit_cell = row.toatoms()

    # Create the supercell (repeated structure)
    supercell = make_supercell(unit_cell, transformation_matrix)

    # Define a filename based on the material's ID in the database
    filename = os.path.join(output_folder, f"supercell_{row.id}.xyz")

    # Write the supercell structure to an XYZ file inside the 'supercells' folder
    write(filename, supercell)

    print(f"Supercell expansion complete for {row.id} and saved to '{filename}'")

   


print(f"Supercell expansion for the all materials in the database is complete and saved in the '{output_folder}' folder.")

# %%
#Supercell generator: flatband

import os
import numpy as np
from ase.io import write
from ase.build import make_supercell
from ase import Atoms
import ast  # Use ast.literal_eval for safer evaluation

SUPERCELL_SIZE = 1

transformation_matrix = np.array([[SUPERCELL_SIZE, 0, 0],
                                  [0, SUPERCELL_SIZE, 0],
                                  [0, 0, 1]])  # No replication in the c-direction

# Create a folder for saving the supercell files
output_folder = 'Supercells/supercells_flatband_1x1'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to parse the structures from the text file
def parse_structures(filename):
    import re
    materials = []
    with open(filename, 'r') as f:
        lines = f.readlines()

    i = 0
    while i < len(lines):
        line = lines[i].strip()
        if line.startswith('2dm-'):
            material = {}
            material['id'] = line.strip()
            i += 1
            # Read formula and code
            line = lines[i].strip()
            formula_and_code = line.split()
            material['formula'] = formula_and_code[0]
            material['some_code'] = formula_and_code[1] if len(formula_and_code) > 1 else ''
            i += 1
            # Read lattice vectors
            if lines[i].strip() == 'lattice vector':
                i += 1
                material['lattice_vectors'] = ast.literal_eval(lines[i].strip())
                i += 1
            else:
                raise ValueError(f"Expected 'lattice vector' at line {i+1}")
            # Skip empty lines
            while i < len(lines) and not lines[i].strip():
                i += 1
            # Read headers
            if i < len(lines):
                headers = lines[i].strip().split()
                i += 1
            else:
                break
            # Read atom data
            atoms = []
            while i < len(lines):
                line = lines[i].strip()
                if not line or line.startswith('2dm-'):
                    break
                # Parse the atom line
                try:
                    atom_dict = parse_atom_line(line)
                    atoms.append(atom_dict)
                except ValueError as e:
                    print(f"Warning: {e}")
                i += 1
            material['atoms'] = atoms
            materials.append(material)
        else:
            i += 1
    return materials

def parse_atom_line(line):
    import re
    # Remove leading index if present
    line = line.strip()
    if line and line[0].isdigit():
        parts = line.split(None, 1)
        line = parts[1]
    # Now extract the label, which is the first word
    parts = line.split(None, 1)
    if len(parts) < 2:
        raise ValueError("Could not parse atom line: {}".format(line))
    label = parts[0]
    rest = parts[1]
    # Use regular expressions to find the content inside brackets or braces
    pattern = r'\[.*?\]|\{.*?\}|[^\s]+'
    matches = re.findall(pattern, rest)
    # The expected order: xyz, abc, species, properties
    if len(matches) >= 4:
        xyz_str = matches[0]
        abc_str = matches[1]
        species_str = matches[2]
        properties_str = matches[3]
        return {
            'label': label,
            'xyz': xyz_str,
            'abc': abc_str,
            'species': species_str,
            'properties': properties_str
        }
    else:
        raise ValueError("Could not parse atom line: {}".format(line))

# Parse the structures from the text file
materials = parse_structures('Materials/reduced_sublattice_structure.txt')

# Iterate over the parsed materials and generate supercells
for material in materials:
    # Extract lattice vectors and atom data
    cell = material['lattice_vectors']
    atoms_data = material['atoms']
    symbols = []
    positions = []
    for atom in atoms_data:
        symbol = atom['label']
        position = ast.literal_eval(atom['xyz'])  # Safely convert string to list
        symbols.append(symbol)
        positions.append(position)
    # Create the unit cell structure
    unit_cell = Atoms(symbols=symbols, positions=positions, cell=cell, pbc=[True, True, False])
    # Create the supercell
    supercell = make_supercell(unit_cell, transformation_matrix)
    # Define the output filename
    filename = os.path.join(output_folder, f"supercell_{material['id']}.xyz")
    # Write the supercell to a file
    write(filename, supercell)
    print(f"Supercell expansion complete for {material['id']} and saved to '{filename}'")

print(f"Supercell expansion for all materials is complete and saved in the '{output_folder}' folder.")

# %%
#Supercell generator: flatband with rotation

import os
import numpy as np
from ase.io import write
from ase.build import make_supercell
from ase import Atoms
import ast  # Use ast.literal_eval for safer evaluation
from scipy.spatial.transform import Rotation as R  # For rotation operations

SUPERCELL_SIZE = 3

transformation_matrix = np.array([[SUPERCELL_SIZE, 0, 0],
                                  [0, SUPERCELL_SIZE, 0],
                                  [0, 0, 1]])  # No replication in the c-direction

# Create a folder for saving the supercell files
output_folder = 'Supercells/supercells_flatband_rotated_3x3'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to parse the structures from the text file
def parse_structures(filename):
    import re
    materials = []
    with open(filename, 'r') as f:
        lines = f.readlines()

    i = 0
    while i < len(lines):
        line = lines[i].strip()
        if line.startswith('2dm-'):
            material = {}
            material['id'] = line.strip()
            i += 1
            # Read formula and code
            line = lines[i].strip()
            formula_and_code = line.split()
            material['formula'] = formula_and_code[0]
            material['some_code'] = formula_and_code[1] if len(formula_and_code) > 1 else ''
            i += 1
            # Read lattice vectors
            if lines[i].strip() == 'lattice vector':
                i += 1
                material['lattice_vectors'] = ast.literal_eval(lines[i].strip())
                i += 1
            else:
                raise ValueError(f"Expected 'lattice vector' at line {i+1}")
            # Skip empty lines
            while i < len(lines) and not lines[i].strip():
                i += 1
            # Read headers
            if i < len(lines):
                headers = lines[i].strip().split()
                i += 1
            else:
                break
            # Read atom data
            atoms = []
            while i < len(lines):
                line = lines[i].strip()
                if not line or line.startswith('2dm-'):
                    break
                # Parse the atom line
                try:
                    atom_dict = parse_atom_line(line)
                    atoms.append(atom_dict)
                except ValueError as e:
                    print(f"Warning: {e}")
                i += 1
            material['atoms'] = atoms
            materials.append(material)
        else:
            i += 1
    return materials

def parse_atom_line(line):
    import re
    # Remove leading index if present
    line = line.strip()
    if line and line[0].isdigit():
        parts = line.split(None, 1)
        line = parts[1]
    # Now extract the label, which is the first word
    parts = line.split(None, 1)
    if len(parts) < 2:
        raise ValueError("Could not parse atom line: {}".format(line))
    label = parts[0]
    rest = parts[1]
    # Use regular expressions to find the content inside brackets or braces
    pattern = r'\[.*?\]|\{.*?\}|[^\s]+'
    matches = re.findall(pattern, rest)
    # The expected order: xyz, abc, species, properties
    if len(matches) >= 4:
        xyz_str = matches[0]
        abc_str = matches[1]
        species_str = matches[2]
        properties_str = matches[3]
        return {
            'label': label,
            'xyz': xyz_str,
            'abc': abc_str,
            'species': species_str,
            'properties': properties_str
        }
    else:
        raise ValueError("Could not parse atom line: {}".format(line))

# Parse the structures from the text file
materials = parse_structures('Materials/reduced_sublattice_structure.txt')

# Iterate over the parsed materials and generate supercells
for material in materials:
    # Extract lattice vectors and atom data
    cell = np.array(material['lattice_vectors'], dtype=float)  # Convert to numpy array
    atoms_data = material['atoms']
    symbols = []
    positions = []
    for atom in atoms_data:
        symbol = atom['label']
        position = np.array(ast.literal_eval(atom['xyz']), dtype=float)  # Safely convert string to array
        symbols.append(symbol)
        positions.append(position)
    positions = np.array(positions)  # Convert to numpy array

    # Get lattice vectors a and b
    a = cell[0]
    b = cell[1]

    # Check if the z-components of both a and b are zero (within a small tolerance)
    if np.isclose(a[2], 0.0, atol=1e-6) and np.isclose(b[2], 0.0, atol=1e-6):
        # No rotation needed
        rotation_matrix = np.eye(3)
    else:
        # Step 1: Compute the rotation matrix to align the lattice plane with the xy-plane
        # Compute the normal vector to the plane defined by a and b
        normal_vector = np.cross(a, b)
        normal_vector /= np.linalg.norm(normal_vector)  # Normalize

        # Compute the angle between the normal vector and the z-axis
        z_axis = np.array([0, 0, 1])
        dot_product = np.dot(normal_vector, z_axis)
        rotation_angle = np.arccos(np.clip(dot_product, -1.0, 1.0))

        # Compute rotation axis
        rotation_axis = np.cross(normal_vector, z_axis)
        if np.linalg.norm(rotation_axis) < 1e-6:
            rotation_axis = np.array([1.0, 0.0, 0.0])  # Arbitrary axis as float
        else:
            rotation_axis /= np.linalg.norm(rotation_axis)  # Normalize

        # Create the rotation matrix
        rotation = R.from_rotvec(rotation_angle * rotation_axis)
        rotation_matrix = rotation.as_matrix()

    # Step 2: Apply the rotation to cell and positions
    rotated_cell = (rotation_matrix @ cell.T).T  # Transpose back to (3, 3)
    rotated_positions = (rotation_matrix @ positions.T).T

    # Optional: Round small values to zero for better numerical stability
    rotated_cell[np.abs(rotated_cell) < 1e-8] = 0.0
    rotated_positions[np.abs(rotated_positions) < 1e-8] = 0.0

    # Step 3: Create the unit cell structure with rotated cell and positions
    unit_cell = Atoms(symbols=symbols, positions=rotated_positions, cell=rotated_cell, pbc=[True, True, False])

    # Create the supercell
    supercell = make_supercell(unit_cell, transformation_matrix)

    # Define the output filename
    filename = os.path.join(output_folder, f"rotated_supercell_{material['id']}.xyz")

    # Write the supercell to a file using 'extxyz' format
    write(filename, supercell, format='extxyz')
    print(f"Supercell expansion complete for {material['id']} and saved to '{filename}'")

print(f"Supercell expansion for all materials is complete and saved in the '{output_folder}' folder.")

# %%
#Supercell generator: flatband with rotation and shifts with revised logic
import os
import numpy as np
from ase.io import write
from ase.build import make_supercell
from ase import Atoms
import ast
from scipy.spatial.transform import Rotation as R

SUPERCELL_SIZE = 3

transformation_matrix = np.array([[SUPERCELL_SIZE, 0, 0],
                                  [0, SUPERCELL_SIZE, 0],
                                  [0, 0, 1]])

# Create a folder for saving the supercell files
output_folder = 'Supercells/supercells_flatband_rotated_shifted_3x3'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to parse the structures from the text file
def parse_structures(filename):
    import re
    materials = []
    with open(filename, 'r') as f:
        lines = f.readlines()

    i = 0
    while i < len(lines):
        line = lines[i].strip()
        if line.startswith('2dm-'):
            material = {}
            material['id'] = line.strip()
            i += 1
            # Read formula and code
            line = lines[i].strip()
            formula_and_code = line.split()
            material['formula'] = formula_and_code[0]
            material['some_code'] = formula_and_code[1] if len(formula_and_code) > 1 else ''
            i += 1
            # Read lattice vectors
            if lines[i].strip() == 'lattice vector':
                i += 1
                material['lattice_vectors'] = ast.literal_eval(lines[i].strip())
                i += 1
            else:
                raise ValueError(f"Expected 'lattice vector' at line {i+1}")
            # Skip empty lines
            while i < len(lines) and not lines[i].strip():
                i += 1
            # Read headers
            if i < len(lines):
                headers = lines[i].strip().split()
                i += 1
            else:
                break
            # Read atom data
            atoms = []
            while i < len(lines):
                line = lines[i].strip()
                if not line or line.startswith('2dm-'):
                    break
                # Parse the atom line
                try:
                    atom_dict = parse_atom_line(line)
                    atoms.append(atom_dict)
                except ValueError as e:
                    print(f"Warning: {e}")
                i += 1
            material['atoms'] = atoms
            materials.append(material)
        else:
            i += 1
    return materials

def parse_atom_line(line):
    import re
    # Remove leading index if present
    line = line.strip()
    if line and line[0].isdigit():
        parts = line.split(None, 1)
        line = parts[1]
    # Now extract the label, which is the first word
    parts = line.split(None, 1)
    if len(parts) < 2:
        raise ValueError("Could not parse atom line: {}".format(line))
    label = parts[0]
    rest = parts[1]
    # Use regular expressions to find the content inside brackets or braces
    pattern = r'\[.*?\]|\{.*?\}|[^\s]+'
    matches = re.findall(pattern, rest)
    # The expected order: xyz, abc, species, properties
    if len(matches) >= 4:
        xyz_str = matches[0]
        abc_str = matches[1]
        species_str = matches[2]
        properties_str = matches[3]
        return {
            'label': label,
            'xyz': xyz_str,
            'abc': abc_str,
            'species': species_str,
            'properties': properties_str
        }
    else:
        raise ValueError("Could not parse atom line: {}".format(line))


# Parse the structures from the text file
materials = parse_structures('Materials/reduced_sublattice_structure.txt')

# Iterate over the parsed materials and generate supercells
for material in materials:
    # Extract lattice vectors and atom data
    cell = np.array(material['lattice_vectors'], dtype=float)  # Convert to numpy array
    atoms_data = material['atoms']
    symbols = []
    positions = []
    for atom in atoms_data:
        symbol = atom['label']
        position = np.array(ast.literal_eval(atom['xyz']), dtype=float)  # Safely convert string to array
        symbols.append(symbol)
        positions.append(position)
    positions = np.array(positions)  # Convert to numpy array

    # Get lattice vectors a and b
    a = cell[0]
    b = cell[1]
    c_vector = cell[2]

    # Check if the z-components of both a and b are zero (within a small tolerance)
    if np.isclose(a[2], 0.0, atol=1e-6) and np.isclose(b[2], 0.0, atol=1e-6):
        # No rotation needed
        rotation_matrix = np.eye(3)
        print(f"No rotation applied for {material['id']} as z-components of a and b are zero.")
    else:
        # Step 1: Compute the rotation matrix to align the lattice plane with the xy-plane
        # Compute the normal vector to the plane defined by a and b
        normal_vector = np.cross(a, b)
        normal_vector /= np.linalg.norm(normal_vector)  # Normalize

        # Compute the angle between the normal vector and the z-axis
        z_axis = np.array([0, 0, 1])
        dot_product = np.dot(normal_vector, z_axis)
        rotation_angle = np.arccos(np.clip(dot_product, -1.0, 1.0))

        # Compute rotation axis
        rotation_axis = np.cross(normal_vector, z_axis)
        if np.linalg.norm(rotation_axis) < 1e-6:
            rotation_axis = np.array([1.0, 0.0, 0.0])  # Arbitrary axis as float
        else:
            rotation_axis /= np.linalg.norm(rotation_axis)  # Normalize

        # Create the rotation matrix
        rotation = R.from_rotvec(rotation_angle * rotation_axis)
        rotation_matrix = rotation.as_matrix()

        print(f"Rotation applied for {material['id']}.")

    # Step 2: Apply the rotation to cell and positions
    rotated_cell = (rotation_matrix @ cell.T).T  # Transpose back to (3, 3)
    rotated_positions = (rotation_matrix @ positions.T).T

    # Round small values to zero for better numerical stability
    rotated_cell[np.abs(rotated_cell) < 1e-8] = 0.0
    rotated_positions[np.abs(rotated_positions) < 1e-8] = 0.0

    # Step 3: Create the unit cell structure with rotated cell and positions
    unit_cell = Atoms(symbols=symbols, positions=rotated_positions, cell=rotated_cell, pbc=[True, True, False])

    # **New Step: Adjust Layers Along the c-axis**
    # Get scaled positions
    scaled_positions = unit_cell.get_scaled_positions()
    z_scaled = scaled_positions[:, 2]

    # Determine if layers are at the cell boundaries
    z_min = np.min(z_scaled)
    z_max = np.max(z_scaled)
    z_range = z_max - z_min

    # Define thresholds
    threshold_low = 0.25
    threshold_high = 0.75

    # Check if atoms are near z=0 or z=1
    adjust_needed = False
    if z_min < threshold_low and z_max > threshold_high:
        adjust_needed = True
        print(f"Adjustment needed for {material['id']} to center layers along the c-axis.")

        # Compute mean z position considering periodicity
        angles = 2 * np.pi * z_scaled
        complex_numbers = np.exp(1j * angles)
        mean_complex = np.mean(complex_numbers)
        mean_angle = np.angle(mean_complex)
        z_mean = mean_angle / (2 * np.pi)
        if z_mean < 0:
            z_mean += 1  # Ensure z_mean is within [0,1)

        # Compute shift to bring z_mean to 0.5
        shift = 0.5 - z_mean

        # Shift all atoms
        scaled_positions[:, 2] += shift

        # Ensure scaled positions are within [0,1)
        scaled_positions[:, 2] = np.mod(scaled_positions[:, 2], 1.0)

        # Update positions
        unit_cell.set_scaled_positions(scaled_positions)


    # Proceed to create the supercell
    supercell = make_supercell(unit_cell, transformation_matrix)

    # Define the output filename
    filename = os.path.join(output_folder, f"supercell_{material['id']}.xyz")

    # Write the supercell to a file using 'extxyz' format
    write(filename, supercell, format='extxyz')
    print(f"Supercell expansion complete for {material['id']} and saved to '{filename}'\n")

print(f"Supercell expansion for all materials is complete and saved in the '{output_folder}' folder.")

# %%
#Supercell generator: flatband with rotation and shifts with revised logic and rotated to align a and x
import os
import numpy as np
from ase.io import write
from ase.build import make_supercell
from ase import Atoms
import ast
from scipy.spatial.transform import Rotation as R

SUPERCELL_SIZE = 10

transformation_matrix = np.array([[SUPERCELL_SIZE, 0, 0],
                                  [0, SUPERCELL_SIZE, 0],
                                  [0, 0, 1]])

# Create a folder for saving the supercell files
output_folder = 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to parse the structures from the text file
def parse_structures(filename):
    import re
    materials = []
    with open(filename, 'r') as f:
        lines = f.readlines()

    i = 0
    while i < len(lines):
        line = lines[i].strip()
        if line.startswith('2dm-'):
            material = {}
            material['id'] = line.strip()
            i += 1
            # Read formula and code
            line = lines[i].strip()
            formula_and_code = line.split()
            material['formula'] = formula_and_code[0]
            material['some_code'] = formula_and_code[1] if len(formula_and_code) > 1 else ''
            i += 1
            # Read lattice vectors
            if lines[i].strip() == 'lattice vector':
                i += 1
                material['lattice_vectors'] = ast.literal_eval(lines[i].strip())
                i += 1
            else:
                raise ValueError(f"Expected 'lattice vector' at line {i+1}")
            # Skip empty lines
            while i < len(lines) and not lines[i].strip():
                i += 1
            # Read headers
            if i < len(lines):
                headers = lines[i].strip().split()
                i += 1
            else:
                break
            # Read atom data
            atoms = []
            while i < len(lines):
                line = lines[i].strip()
                if not line or line.startswith('2dm-'):
                    break
                # Parse the atom line
                try:
                    atom_dict = parse_atom_line(line)
                    atoms.append(atom_dict)
                except ValueError as e:
                    print(f"Warning: {e}")
                i += 1
            material['atoms'] = atoms
            materials.append(material)
        else:
            i += 1
    return materials

def parse_atom_line(line):
    import re
    # Remove leading index if present
    line = line.strip()
    if line and line[0].isdigit():
        parts = line.split(None, 1)
        line = parts[1]
    # Now extract the label, which is the first word
    parts = line.split(None, 1)
    if len(parts) < 2:
        raise ValueError("Could not parse atom line: {}".format(line))
    label = parts[0]
    rest = parts[1]
    # Use regular expressions to find the content inside brackets or braces
    pattern = r'\[.*?\]|\{.*?\}|[^\s]+'
    matches = re.findall(pattern, rest)
    # The expected order: xyz, abc, species, properties
    if len(matches) >= 4:
        xyz_str = matches[0]
        abc_str = matches[1]
        species_str = matches[2]
        properties_str = matches[3]
        return {
            'label': label,
            'xyz': xyz_str,
            'abc': abc_str,
            'species': species_str,
            'properties': properties_str
        }
    else:
        raise ValueError("Could not parse atom line: {}".format(line))


# Parse the structures from the text file
materials = parse_structures('Materials/reduced_sublattice_structure.txt')

# Iterate over the parsed materials and generate supercells
for material in materials:
    # Extract lattice vectors and atom data
    cell = np.array(material['lattice_vectors'], dtype=float)  # Convert to numpy array
    atoms_data = material['atoms']
    symbols = []
    positions = []
    for atom in atoms_data:
        symbol = atom['label']
        position = np.array(ast.literal_eval(atom['xyz']), dtype=float)  # Safely convert string to array
        symbols.append(symbol)
        positions.append(position)
    positions = np.array(positions)  # Convert to numpy array

    # Get lattice vectors a and b
    a = cell[0]
    b = cell[1]
    c_vector = cell[2]

    # Check if the z-components of both a and b are zero (within a small tolerance)
    if np.isclose(a[2], 0.0, atol=1e-6) and np.isclose(b[2], 0.0, atol=1e-6):
        # No rotation needed
        rotation_matrix = np.eye(3)
        print(f"No rotation applied for {material['id']} as z-components of a and b are zero.")
        rotated_cell = cell.copy()
        rotated_positions = positions.copy()
    else:
        # Step 1: Compute the rotation matrix to align the lattice plane with the xy-plane
        # Compute the normal vector to the plane defined by a and b
        normal_vector = np.cross(a, b)
        normal_vector /= np.linalg.norm(normal_vector)  # Normalize

        # Compute the angle between the normal vector and the z-axis
        z_axis = np.array([0, 0, 1])
        dot_product = np.dot(normal_vector, z_axis)
        rotation_angle = np.arccos(np.clip(dot_product, -1.0, 1.0))

        # Compute rotation axis
        rotation_axis = np.cross(normal_vector, z_axis)
        if np.linalg.norm(rotation_axis) < 1e-6:
            rotation_axis = np.array([1.0, 0.0, 0.0])  # Arbitrary axis as float
        else:
            rotation_axis /= np.linalg.norm(rotation_axis)  # Normalize

        # Create the rotation matrix
        rotation = R.from_rotvec(rotation_angle * rotation_axis)
        rotation_matrix = rotation.as_matrix()

        print(f"Rotation applied for {material['id']} to align lattice plane with xy-plane.")

        # Apply the rotation to cell and positions
        rotated_cell = (rotation_matrix @ cell.T).T  # Transpose back to (3, 3)
        rotated_positions = (rotation_matrix @ positions.T).T

    # Step 2: Rotate around z-axis to align a along x-axis
    a_rotated = rotated_cell[0]
    a_xy = a_rotated[:2]  # components in x and y
    norm_a_xy = np.linalg.norm(a_xy)

    if norm_a_xy > 1e-6:
        theta = np.arctan2(a_xy[1], a_xy[0])  # angle between a_rotated and x-axis

        # Create rotation matrix for rotation about z-axis by angle -theta
        rotation_z = np.array([[np.cos(-theta), -np.sin(-theta), 0],
                               [np.sin(-theta),  np.cos(-theta), 0],
                               [            0,              0,    1]])

        # Apply this rotation to rotated_cell and rotated_positions
        rotated_cell = (rotation_z @ rotated_cell.T).T
        rotated_positions = (rotation_z @ rotated_positions.T).T

        print(f"Additional rotation applied around z-axis to align a along x-axis for {material['id']}.")
    else:
        print(f"Lattice vector a is already aligned with x-axis for {material['id']}.")

    # Round small values to zero for better numerical stability
    rotated_cell[np.abs(rotated_cell) < 1e-8] = 0.0
    rotated_positions[np.abs(rotated_positions) < 1e-8] = 0.0

    # Step 3: Create the unit cell structure with rotated cell and positions
    unit_cell = Atoms(symbols=symbols, positions=rotated_positions, cell=rotated_cell, pbc=[True, True, False])

    # **New Step: Adjust Layers Along the c-axis**
    # Get scaled positions
    scaled_positions = unit_cell.get_scaled_positions()
    z_scaled = scaled_positions[:, 2]

    # Determine if layers are at the cell boundaries
    z_min = np.min(z_scaled)
    z_max = np.max(z_scaled)
    z_range = z_max - z_min

    # Define thresholds
    threshold_low = 0.25
    threshold_high = 0.75

    # Check if atoms are near z=0 or z=1
    adjust_needed = False
    if z_min < threshold_low and z_max > threshold_high:
        adjust_needed = True
        print(f"Adjustment needed for {material['id']} to center layers along the c-axis.")

        # Compute mean z position considering periodicity
        angles = 2 * np.pi * z_scaled
        complex_numbers = np.exp(1j * angles)
        mean_complex = np.mean(complex_numbers)
        mean_angle = np.angle(mean_complex)
        z_mean = mean_angle / (2 * np.pi)
        if z_mean < 0:
            z_mean += 1  # Ensure z_mean is within [0,1)

        # Compute shift to bring z_mean to 0.5
        shift = 0.5 - z_mean

        # Shift all atoms
        scaled_positions[:, 2] += shift

        # Ensure scaled positions are within [0,1)
        scaled_positions[:, 2] = np.mod(scaled_positions[:, 2], 1.0)

        # Update positions
        unit_cell.set_scaled_positions(scaled_positions)


    # Proceed to create the supercell
    supercell = make_supercell(unit_cell, transformation_matrix)

    # Define the output filename
    filename = os.path.join(output_folder, f"supercell_{material['id']}.xyz")

    # Write the supercell to a file using 'extxyz' format
    write(filename, supercell, format='extxyz')
    print(f"Supercell expansion complete for {material['id']} and saved to '{filename}'\n")

print(f"Supercell expansion for all materials is complete and saved in the '{output_folder}' folder.")
# Out:
# No rotation applied for 2dm-21 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-21.
# Supercell expansion complete for 2dm-21 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-21.xyz'
#
# Rotation applied for 2dm-22 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-22.
# Supercell expansion complete for 2dm-22 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-22.xyz'
#
# No rotation applied for 2dm-25 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-25.
# Supercell expansion complete for 2dm-25 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-25.xyz'
#
# Rotation applied for 2dm-29 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-29.
# Adjustment needed for 2dm-29 to center layers along the c-axis.
# Supercell expansion complete for 2dm-29 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-29.xyz'
#
# Rotation applied for 2dm-31 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-31.
# Adjustment needed for 2dm-31 to center layers along the c-axis.
# Supercell expansion complete for 2dm-31 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-31.xyz'
#
# Rotation applied for 2dm-32 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-32.
# Supercell expansion complete for 2dm-32 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-32.xyz'
#
# No rotation applied for 2dm-34 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-34.
# Supercell expansion complete for 2dm-34 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-34.xyz'
#
# Rotation applied for 2dm-41 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-41.
# Supercell expansion complete for 2dm-41 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-41.xyz'
#
# No rotation applied for 2dm-56 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-56.
# Adjustment needed for 2dm-56 to center layers along the c-axis.
# Supercell expansion complete for 2dm-56 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-56.xyz'
#
# No rotation applied for 2dm-6370 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-6370.
# Supercell expansion complete for 2dm-6370 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-6370.xyz'
#
# Rotation applied for 2dm-79 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-79.
# Adjustment needed for 2dm-79 to center layers along the c-axis.
# Supercell expansion complete for 2dm-79 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-79.xyz'
#
# Rotation applied for 2dm-85 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-85.
# Adjustment needed for 2dm-85 to center layers along the c-axis.
# Supercell expansion complete for 2dm-85 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-85.xyz'
#
# Rotation applied for 2dm-86 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-86.
# Adjustment needed for 2dm-86 to center layers along the c-axis.
# Supercell expansion complete for 2dm-86 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-86.xyz'
#
# No rotation applied for 2dm-89 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-89.
# Supercell expansion complete for 2dm-89 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-89.xyz'
#
# Rotation applied for 2dm-92 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-92.
# Supercell expansion complete for 2dm-92 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-92.xyz'
#
# No rotation applied for 2dm-101 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-101.
# Adjustment needed for 2dm-101 to center layers along the c-axis.
# Supercell expansion complete for 2dm-101 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-101.xyz'
#
# Rotation applied for 2dm-103 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-103.
# Adjustment needed for 2dm-103 to center layers along the c-axis.
# Supercell expansion complete for 2dm-103 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-103.xyz'
#
# No rotation applied for 2dm-104 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-104.
# Adjustment needed for 2dm-104 to center layers along the c-axis.
# Supercell expansion complete for 2dm-104 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-104.xyz'
#
# Rotation applied for 2dm-107 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-107.
# Adjustment needed for 2dm-107 to center layers along the c-axis.
# Supercell expansion complete for 2dm-107 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-107.xyz'
#
# Rotation applied for 2dm-111 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-111.
# Adjustment needed for 2dm-111 to center layers along the c-axis.
# Supercell expansion complete for 2dm-111 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-111.xyz'
#
# No rotation applied for 2dm-119 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-119.
# Adjustment needed for 2dm-119 to center layers along the c-axis.
# Supercell expansion complete for 2dm-119 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-119.xyz'
#
# Rotation applied for 2dm-121 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-121.
# Adjustment needed for 2dm-121 to center layers along the c-axis.
# Supercell expansion complete for 2dm-121 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-121.xyz'
#
# No rotation applied for 2dm-125 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-125.
# Supercell expansion complete for 2dm-125 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-125.xyz'
#
# Rotation applied for 2dm-128 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-128.
# Supercell expansion complete for 2dm-128 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-128.xyz'
#
# Rotation applied for 2dm-129 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-129.
# Supercell expansion complete for 2dm-129 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-129.xyz'
#
# No rotation applied for 2dm-131 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-131.
# Supercell expansion complete for 2dm-131 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-131.xyz'
#
# No rotation applied for 2dm-138 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-138.
# Adjustment needed for 2dm-138 to center layers along the c-axis.
# Supercell expansion complete for 2dm-138 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-138.xyz'
#
# Rotation applied for 2dm-142 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-142.
# Supercell expansion complete for 2dm-142 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-142.xyz'
#
# Rotation applied for 2dm-144 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-144.
# Adjustment needed for 2dm-144 to center layers along the c-axis.
# Supercell expansion complete for 2dm-144 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-144.xyz'
#
# No rotation applied for 2dm-147 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-147.
# Supercell expansion complete for 2dm-147 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-147.xyz'
#
# Rotation applied for 2dm-149 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-149.
# Adjustment needed for 2dm-149 to center layers along the c-axis.
# Supercell expansion complete for 2dm-149 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-149.xyz'
#
# No rotation applied for 2dm-153 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-153.
# Adjustment needed for 2dm-153 to center layers along the c-axis.
# Supercell expansion complete for 2dm-153 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-153.xyz'
#
# Rotation applied for 2dm-154 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-154.
# Supercell expansion complete for 2dm-154 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-154.xyz'
#
# No rotation applied for 2dm-155 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-155.
# Supercell expansion complete for 2dm-155 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-155.xyz'
#
# Rotation applied for 2dm-157 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-157.
# Supercell expansion complete for 2dm-157 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-157.xyz'
#
# Rotation applied for 2dm-161 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-161.
# Adjustment needed for 2dm-161 to center layers along the c-axis.
# Supercell expansion complete for 2dm-161 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-161.xyz'
#
# Rotation applied for 2dm-164 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-164.
# Supercell expansion complete for 2dm-164 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-164.xyz'
#
# No rotation applied for 2dm-165 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-165.
# Adjustment needed for 2dm-165 to center layers along the c-axis.
# Supercell expansion complete for 2dm-165 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-165.xyz'
#
# No rotation applied for 2dm-167 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-167.
# Adjustment needed for 2dm-167 to center layers along the c-axis.
# Supercell expansion complete for 2dm-167 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-167.xyz'
#
# Rotation applied for 2dm-170 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-170.
# Supercell expansion complete for 2dm-170 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-170.xyz'
#
# Rotation applied for 2dm-180 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-180.
# Adjustment needed for 2dm-180 to center layers along the c-axis.
# Supercell expansion complete for 2dm-180 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-180.xyz'
#
# Rotation applied for 2dm-183 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-183.
# Supercell expansion complete for 2dm-183 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-183.xyz'
#
# No rotation applied for 2dm-190 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-190.
# Supercell expansion complete for 2dm-190 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-190.xyz'
#
# Rotation applied for 2dm-192 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-192.
# Supercell expansion complete for 2dm-192 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-192.xyz'
#
# Rotation applied for 2dm-197 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-197.
# Supercell expansion complete for 2dm-197 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-197.xyz'
#
# Rotation applied for 2dm-200 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-200.
# Supercell expansion complete for 2dm-200 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-200.xyz'
#
# No rotation applied for 2dm-202 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-202.
# Adjustment needed for 2dm-202 to center layers along the c-axis.
# Supercell expansion complete for 2dm-202 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-202.xyz'
#
# No rotation applied for 2dm-205 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-205.
# Supercell expansion complete for 2dm-205 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-205.xyz'
#
# Rotation applied for 2dm-206 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-206.
# Adjustment needed for 2dm-206 to center layers along the c-axis.
# Supercell expansion complete for 2dm-206 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-206.xyz'
#
# No rotation applied for 2dm-209 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-209.
# Supercell expansion complete for 2dm-209 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-209.xyz'
#
# Rotation applied for 2dm-213 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-213.
# Adjustment needed for 2dm-213 to center layers along the c-axis.
# Supercell expansion complete for 2dm-213 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-213.xyz'
#
# No rotation applied for 2dm-214 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-214.
# Supercell expansion complete for 2dm-214 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-214.xyz'
#
# No rotation applied for 2dm-218 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-218.
# Adjustment needed for 2dm-218 to center layers along the c-axis.
# Supercell expansion complete for 2dm-218 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-218.xyz'
#
# Rotation applied for 2dm-222 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-222.
# Adjustment needed for 2dm-222 to center layers along the c-axis.
# Supercell expansion complete for 2dm-222 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-222.xyz'
#
# Rotation applied for 2dm-224 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-224.
# Adjustment needed for 2dm-224 to center layers along the c-axis.
# Supercell expansion complete for 2dm-224 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-224.xyz'
#
# Rotation applied for 2dm-229 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-229.
# Supercell expansion complete for 2dm-229 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-229.xyz'
#
# Rotation applied for 2dm-230 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-230.
# Adjustment needed for 2dm-230 to center layers along the c-axis.
# Supercell expansion complete for 2dm-230 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-230.xyz'
#
# Rotation applied for 2dm-231 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-231.
# Supercell expansion complete for 2dm-231 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-231.xyz'
#
# Rotation applied for 2dm-233 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-233.
# Supercell expansion complete for 2dm-233 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-233.xyz'
#
# Rotation applied for 2dm-234 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-234.
# Adjustment needed for 2dm-234 to center layers along the c-axis.
# Supercell expansion complete for 2dm-234 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-234.xyz'
#
# No rotation applied for 2dm-238 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-238.
# Supercell expansion complete for 2dm-238 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-238.xyz'
#
# Rotation applied for 2dm-245 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-245.
# Adjustment needed for 2dm-245 to center layers along the c-axis.
# Supercell expansion complete for 2dm-245 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-245.xyz'
#
# Rotation applied for 2dm-248 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-248.
# Supercell expansion complete for 2dm-248 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-248.xyz'
#
# No rotation applied for 2dm-249 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-249.
# Adjustment needed for 2dm-249 to center layers along the c-axis.
# Supercell expansion complete for 2dm-249 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-249.xyz'
#
# Rotation applied for 2dm-250 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-250.
# Supercell expansion complete for 2dm-250 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-250.xyz'
#
# No rotation applied for 2dm-257 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-257.
# Adjustment needed for 2dm-257 to center layers along the c-axis.
# Supercell expansion complete for 2dm-257 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-257.xyz'
#
# Rotation applied for 2dm-258 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-258.
# Adjustment needed for 2dm-258 to center layers along the c-axis.
# Supercell expansion complete for 2dm-258 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-258.xyz'
#
# Rotation applied for 2dm-259 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-259.
# Adjustment needed for 2dm-259 to center layers along the c-axis.
# Supercell expansion complete for 2dm-259 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-259.xyz'
#
# No rotation applied for 2dm-263 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-263.
# Adjustment needed for 2dm-263 to center layers along the c-axis.
# Supercell expansion complete for 2dm-263 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-263.xyz'
#
# Rotation applied for 2dm-264 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-264.
# Adjustment needed for 2dm-264 to center layers along the c-axis.
# Supercell expansion complete for 2dm-264 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-264.xyz'
#
# No rotation applied for 2dm-265 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-265.
# Adjustment needed for 2dm-265 to center layers along the c-axis.
# Supercell expansion complete for 2dm-265 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-265.xyz'
#
# No rotation applied for 2dm-269 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-269.
# Adjustment needed for 2dm-269 to center layers along the c-axis.
# Supercell expansion complete for 2dm-269 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-269.xyz'
#
# Rotation applied for 2dm-271 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-271.
# Adjustment needed for 2dm-271 to center layers along the c-axis.
# Supercell expansion complete for 2dm-271 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-271.xyz'
#
# Rotation applied for 2dm-277 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-277.
# Adjustment needed for 2dm-277 to center layers along the c-axis.
# Supercell expansion complete for 2dm-277 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-277.xyz'
#
# No rotation applied for 2dm-290 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-290.
# Adjustment needed for 2dm-290 to center layers along the c-axis.
# Supercell expansion complete for 2dm-290 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-290.xyz'
#
# No rotation applied for 2dm-293 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-293.
# Adjustment needed for 2dm-293 to center layers along the c-axis.
# Supercell expansion complete for 2dm-293 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-293.xyz'
#
# Rotation applied for 2dm-300 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-300.
# Adjustment needed for 2dm-300 to center layers along the c-axis.
# Supercell expansion complete for 2dm-300 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-300.xyz'
#
# Rotation applied for 2dm-301 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-301.
# Adjustment needed for 2dm-301 to center layers along the c-axis.
# Supercell expansion complete for 2dm-301 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-301.xyz'
#
# Rotation applied for 2dm-303 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-303.
# Supercell expansion complete for 2dm-303 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-303.xyz'
#
# No rotation applied for 2dm-304 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-304.
# Adjustment needed for 2dm-304 to center layers along the c-axis.
# Supercell expansion complete for 2dm-304 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-304.xyz'
#
# Rotation applied for 2dm-306 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-306.
# Supercell expansion complete for 2dm-306 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-306.xyz'
#
# No rotation applied for 2dm-308 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-308.
# Supercell expansion complete for 2dm-308 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-308.xyz'
#
# No rotation applied for 2dm-318 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-318.
# Supercell expansion complete for 2dm-318 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-318.xyz'
#
# Rotation applied for 2dm-319 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-319.
# Supercell expansion complete for 2dm-319 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-319.xyz'
#
# Rotation applied for 2dm-320 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-320.
# Supercell expansion complete for 2dm-320 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-320.xyz'
#
# No rotation applied for 2dm-321 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-321.
# Supercell expansion complete for 2dm-321 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-321.xyz'
#
# Rotation applied for 2dm-324 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-324.
# Adjustment needed for 2dm-324 to center layers along the c-axis.
# Supercell expansion complete for 2dm-324 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-324.xyz'
#
# No rotation applied for 2dm-325 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-325.
# Adjustment needed for 2dm-325 to center layers along the c-axis.
# Supercell expansion complete for 2dm-325 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-325.xyz'
#
# No rotation applied for 2dm-326 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-326.
# Adjustment needed for 2dm-326 to center layers along the c-axis.
# Supercell expansion complete for 2dm-326 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-326.xyz'
#
# No rotation applied for 2dm-329 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-329.
# Supercell expansion complete for 2dm-329 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-329.xyz'
#
# Rotation applied for 2dm-333 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-333.
# Adjustment needed for 2dm-333 to center layers along the c-axis.
# Supercell expansion complete for 2dm-333 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-333.xyz'
#
# Rotation applied for 2dm-335 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-335.
# Adjustment needed for 2dm-335 to center layers along the c-axis.
# Supercell expansion complete for 2dm-335 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-335.xyz'
#
# Rotation applied for 2dm-340 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-340.
# Adjustment needed for 2dm-340 to center layers along the c-axis.
# Supercell expansion complete for 2dm-340 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-340.xyz'
#
# No rotation applied for 2dm-342 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-342.
# Adjustment needed for 2dm-342 to center layers along the c-axis.
# Supercell expansion complete for 2dm-342 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-342.xyz'
#
# No rotation applied for 2dm-346 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-346.
# Adjustment needed for 2dm-346 to center layers along the c-axis.
# Supercell expansion complete for 2dm-346 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-346.xyz'
#
# No rotation applied for 2dm-349 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-349.
# Adjustment needed for 2dm-349 to center layers along the c-axis.
# Supercell expansion complete for 2dm-349 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-349.xyz'
#
# Rotation applied for 2dm-350 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-350.
# Supercell expansion complete for 2dm-350 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-350.xyz'
#
# Rotation applied for 2dm-351 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-351.
# Adjustment needed for 2dm-351 to center layers along the c-axis.
# Supercell expansion complete for 2dm-351 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-351.xyz'
#
# No rotation applied for 2dm-356 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-356.
# Supercell expansion complete for 2dm-356 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-356.xyz'
#
# Rotation applied for 2dm-360 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-360.
# Adjustment needed for 2dm-360 to center layers along the c-axis.
# Supercell expansion complete for 2dm-360 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-360.xyz'
#
# Rotation applied for 2dm-361 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-361.
# Supercell expansion complete for 2dm-361 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-361.xyz'
#
# No rotation applied for 2dm-362 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-362.
# Supercell expansion complete for 2dm-362 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-362.xyz'
#
# No rotation applied for 2dm-366 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-366.
# Supercell expansion complete for 2dm-366 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-366.xyz'
#
# Rotation applied for 2dm-369 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-369.
# Adjustment needed for 2dm-369 to center layers along the c-axis.
# Supercell expansion complete for 2dm-369 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-369.xyz'
#
# Rotation applied for 2dm-371 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-371.
# Adjustment needed for 2dm-371 to center layers along the c-axis.
# Supercell expansion complete for 2dm-371 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-371.xyz'
#
# No rotation applied for 2dm-375 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-375.
# Adjustment needed for 2dm-375 to center layers along the c-axis.
# Supercell expansion complete for 2dm-375 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-375.xyz'
#
# No rotation applied for 2dm-376 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-376.
# Adjustment needed for 2dm-376 to center layers along the c-axis.
# Supercell expansion complete for 2dm-376 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-376.xyz'
#
# Rotation applied for 2dm-386 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-386.
# Adjustment needed for 2dm-386 to center layers along the c-axis.
# Supercell expansion complete for 2dm-386 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-386.xyz'
#
# Rotation applied for 2dm-387 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-387.
# Adjustment needed for 2dm-387 to center layers along the c-axis.
# Supercell expansion complete for 2dm-387 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-387.xyz'
#
# No rotation applied for 2dm-390 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-390.
# Supercell expansion complete for 2dm-390 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-390.xyz'
#
# Rotation applied for 2dm-394 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-394.
# Adjustment needed for 2dm-394 to center layers along the c-axis.
# Supercell expansion complete for 2dm-394 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-394.xyz'
#
# Rotation applied for 2dm-396 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-396.
# Supercell expansion complete for 2dm-396 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-396.xyz'
#
# Rotation applied for 2dm-398 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-398.
# Supercell expansion complete for 2dm-398 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-398.xyz'
#
# No rotation applied for 2dm-399 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-399.
# Supercell expansion complete for 2dm-399 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-399.xyz'
#
# Rotation applied for 2dm-401 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-401.
# Adjustment needed for 2dm-401 to center layers along the c-axis.
# Supercell expansion complete for 2dm-401 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-401.xyz'
#
# Rotation applied for 2dm-411 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-411.
# Adjustment needed for 2dm-411 to center layers along the c-axis.
# Supercell expansion complete for 2dm-411 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-411.xyz'
#
# Rotation applied for 2dm-415 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-415.
# Adjustment needed for 2dm-415 to center layers along the c-axis.
# Supercell expansion complete for 2dm-415 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-415.xyz'
#
# No rotation applied for 2dm-419 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-419.
# Supercell expansion complete for 2dm-419 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-419.xyz'
#
# Rotation applied for 2dm-423 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-423.
# Supercell expansion complete for 2dm-423 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-423.xyz'
#
# Rotation applied for 2dm-428 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-428.
# Adjustment needed for 2dm-428 to center layers along the c-axis.
# Supercell expansion complete for 2dm-428 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-428.xyz'
#
# No rotation applied for 2dm-429 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-429.
# Supercell expansion complete for 2dm-429 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-429.xyz'
#
# Rotation applied for 2dm-432 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-432.
# Adjustment needed for 2dm-432 to center layers along the c-axis.
# Supercell expansion complete for 2dm-432 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-432.xyz'
#
# Rotation applied for 2dm-433 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-433.
# Adjustment needed for 2dm-433 to center layers along the c-axis.
# Supercell expansion complete for 2dm-433 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-433.xyz'
#
# Rotation applied for 2dm-438 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-438.
# Adjustment needed for 2dm-438 to center layers along the c-axis.
# Supercell expansion complete for 2dm-438 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-438.xyz'
#
# No rotation applied for 2dm-439 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-439.
# Adjustment needed for 2dm-439 to center layers along the c-axis.
# Supercell expansion complete for 2dm-439 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-439.xyz'
#
# Rotation applied for 2dm-440 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-440.
# Adjustment needed for 2dm-440 to center layers along the c-axis.
# Supercell expansion complete for 2dm-440 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-440.xyz'
#
# No rotation applied for 2dm-441 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-441.
# Supercell expansion complete for 2dm-441 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-441.xyz'
#
# Rotation applied for 2dm-442 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-442.
# Adjustment needed for 2dm-442 to center layers along the c-axis.
# Supercell expansion complete for 2dm-442 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-442.xyz'
#
# Rotation applied for 2dm-448 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-448.
# Supercell expansion complete for 2dm-448 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-448.xyz'
#
# No rotation applied for 2dm-453 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-453.
# Supercell expansion complete for 2dm-453 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-453.xyz'
#
# No rotation applied for 2dm-454 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-454.
# Supercell expansion complete for 2dm-454 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-454.xyz'
#
# Rotation applied for 2dm-456 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-456.
# Adjustment needed for 2dm-456 to center layers along the c-axis.
# Supercell expansion complete for 2dm-456 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-456.xyz'
#
# Rotation applied for 2dm-457 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-457.
# Adjustment needed for 2dm-457 to center layers along the c-axis.
# Supercell expansion complete for 2dm-457 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-457.xyz'
#
# Rotation applied for 2dm-464 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-464.
# Adjustment needed for 2dm-464 to center layers along the c-axis.
# Supercell expansion complete for 2dm-464 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-464.xyz'
#
# No rotation applied for 2dm-470 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-470.
# Adjustment needed for 2dm-470 to center layers along the c-axis.
# Supercell expansion complete for 2dm-470 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-470.xyz'
#
# Rotation applied for 2dm-476 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-476.
# Adjustment needed for 2dm-476 to center layers along the c-axis.
# Supercell expansion complete for 2dm-476 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-476.xyz'
#
# Rotation applied for 2dm-477 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-477.
# Adjustment needed for 2dm-477 to center layers along the c-axis.
# Supercell expansion complete for 2dm-477 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-477.xyz'
#
# Rotation applied for 2dm-478 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-478.
# Adjustment needed for 2dm-478 to center layers along the c-axis.
# Supercell expansion complete for 2dm-478 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-478.xyz'
#
# No rotation applied for 2dm-485 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-485.
# Adjustment needed for 2dm-485 to center layers along the c-axis.
# Supercell expansion complete for 2dm-485 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-485.xyz'
#
# Rotation applied for 2dm-490 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-490.
# Adjustment needed for 2dm-490 to center layers along the c-axis.
# Supercell expansion complete for 2dm-490 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-490.xyz'
#
# Rotation applied for 2dm-492 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-492.
# Adjustment needed for 2dm-492 to center layers along the c-axis.
# Supercell expansion complete for 2dm-492 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-492.xyz'
#
# No rotation applied for 2dm-494 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-494.
# Supercell expansion complete for 2dm-494 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-494.xyz'
#
# Rotation applied for 2dm-495 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-495.
# Supercell expansion complete for 2dm-495 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-495.xyz'
#
# Rotation applied for 2dm-499 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-499.
# Adjustment needed for 2dm-499 to center layers along the c-axis.
# Supercell expansion complete for 2dm-499 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-499.xyz'
#
# Rotation applied for 2dm-505 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-505.
# Supercell expansion complete for 2dm-505 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-505.xyz'
#
# Rotation applied for 2dm-511 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-511.
# Supercell expansion complete for 2dm-511 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-511.xyz'
#
# Rotation applied for 2dm-513 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-513.
# Supercell expansion complete for 2dm-513 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-513.xyz'
#
# No rotation applied for 2dm-516 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-516.
# Adjustment needed for 2dm-516 to center layers along the c-axis.
# Supercell expansion complete for 2dm-516 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-516.xyz'
#
# No rotation applied for 2dm-517 as z-components of a and b are zero.
# ...
#
# No rotation applied for 2dm-5736 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5736.
# Supercell expansion complete for 2dm-5736 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5736.xyz'
#
# No rotation applied for 2dm-5737 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5737.
# Supercell expansion complete for 2dm-5737 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5737.xyz'
#
# No rotation applied for 2dm-5738 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5738.
# Supercell expansion complete for 2dm-5738 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5738.xyz'
#
# No rotation applied for 2dm-5740 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5740.
# Supercell expansion complete for 2dm-5740 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5740.xyz'
#
# No rotation applied for 2dm-5742 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5742.
# Supercell expansion complete for 2dm-5742 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5742.xyz'
#
# No rotation applied for 2dm-5743 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5743.
# Supercell expansion complete for 2dm-5743 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5743.xyz'
#
# Rotation applied for 2dm-5746 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5746.
# Supercell expansion complete for 2dm-5746 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5746.xyz'
#
# No rotation applied for 2dm-5749 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5749.
# Supercell expansion complete for 2dm-5749 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5749.xyz'
#
# Rotation applied for 2dm-5750 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5750.
# Supercell expansion complete for 2dm-5750 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5750.xyz'
#
# No rotation applied for 2dm-5752 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5752.
# Supercell expansion complete for 2dm-5752 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5752.xyz'
#
# Rotation applied for 2dm-5753 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5753.
# Supercell expansion complete for 2dm-5753 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5753.xyz'
#
# No rotation applied for 2dm-5754 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5754.
# Supercell expansion complete for 2dm-5754 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5754.xyz'
#
# No rotation applied for 2dm-5755 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5755.
# Supercell expansion complete for 2dm-5755 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5755.xyz'
#
# Rotation applied for 2dm-5757 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5757.
# Supercell expansion complete for 2dm-5757 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5757.xyz'
#
# No rotation applied for 2dm-5759 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5759.
# Supercell expansion complete for 2dm-5759 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5759.xyz'
#
# No rotation applied for 2dm-5760 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5760.
# Supercell expansion complete for 2dm-5760 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5760.xyz'
#
# No rotation applied for 2dm-5762 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5762.
# Supercell expansion complete for 2dm-5762 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5762.xyz'
#
# Rotation applied for 2dm-5763 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5763.
# Supercell expansion complete for 2dm-5763 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5763.xyz'
#
# No rotation applied for 2dm-5768 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5768.
# Supercell expansion complete for 2dm-5768 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5768.xyz'
#
# No rotation applied for 2dm-5770 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5770.
# Supercell expansion complete for 2dm-5770 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5770.xyz'
#
# No rotation applied for 2dm-5771 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5771.
# Supercell expansion complete for 2dm-5771 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5771.xyz'
#
# No rotation applied for 2dm-5772 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5772.
# Supercell expansion complete for 2dm-5772 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5772.xyz'
#
# Rotation applied for 2dm-5774 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5774.
# Supercell expansion complete for 2dm-5774 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5774.xyz'
#
# No rotation applied for 2dm-5781 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5781.
# Supercell expansion complete for 2dm-5781 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5781.xyz'
#
# No rotation applied for 2dm-5782 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5782.
# Supercell expansion complete for 2dm-5782 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5782.xyz'
#
# Rotation applied for 2dm-5784 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5784.
# Supercell expansion complete for 2dm-5784 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5784.xyz'
#
# No rotation applied for 2dm-5786 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5786.
# Supercell expansion complete for 2dm-5786 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5786.xyz'
#
# No rotation applied for 2dm-5787 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5787.
# Supercell expansion complete for 2dm-5787 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5787.xyz'
#
# No rotation applied for 2dm-5789 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5789.
# Supercell expansion complete for 2dm-5789 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5789.xyz'
#
# No rotation applied for 2dm-5792 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5792.
# Supercell expansion complete for 2dm-5792 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5792.xyz'
#
# No rotation applied for 2dm-5793 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5793.
# Supercell expansion complete for 2dm-5793 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5793.xyz'
#
# No rotation applied for 2dm-5794 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5794.
# Supercell expansion complete for 2dm-5794 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5794.xyz'
#
# Rotation applied for 2dm-5798 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5798.
# Supercell expansion complete for 2dm-5798 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5798.xyz'
#
# No rotation applied for 2dm-5802 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5802.
# Supercell expansion complete for 2dm-5802 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5802.xyz'
#
# Rotation applied for 2dm-5804 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5804.
# Supercell expansion complete for 2dm-5804 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5804.xyz'
#
# No rotation applied for 2dm-5809 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5809.
# Supercell expansion complete for 2dm-5809 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5809.xyz'
#
# No rotation applied for 2dm-5810 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5810.
# Supercell expansion complete for 2dm-5810 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5810.xyz'
#
# No rotation applied for 2dm-5814 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5814.
# Supercell expansion complete for 2dm-5814 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5814.xyz'
#
# No rotation applied for 2dm-5817 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5817.
# Supercell expansion complete for 2dm-5817 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5817.xyz'
#
# No rotation applied for 2dm-5819 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5819.
# Supercell expansion complete for 2dm-5819 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5819.xyz'
#
# No rotation applied for 2dm-5821 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5821.
# Supercell expansion complete for 2dm-5821 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5821.xyz'
#
# No rotation applied for 2dm-5827 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5827.
# Supercell expansion complete for 2dm-5827 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5827.xyz'
#
# No rotation applied for 2dm-5828 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5828.
# Supercell expansion complete for 2dm-5828 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5828.xyz'
#
# No rotation applied for 2dm-5836 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5836.
# Supercell expansion complete for 2dm-5836 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5836.xyz'
#
# No rotation applied for 2dm-5837 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5837.
# Supercell expansion complete for 2dm-5837 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5837.xyz'
#
# No rotation applied for 2dm-5838 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5838.
# Supercell expansion complete for 2dm-5838 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5838.xyz'
#
# No rotation applied for 2dm-5839 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5839.
# Supercell expansion complete for 2dm-5839 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5839.xyz'
#
# Rotation applied for 2dm-5840 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5840.
# Supercell expansion complete for 2dm-5840 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5840.xyz'
#
# No rotation applied for 2dm-5841 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5841.
# Supercell expansion complete for 2dm-5841 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5841.xyz'
#
# Rotation applied for 2dm-5843 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5843.
# Supercell expansion complete for 2dm-5843 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5843.xyz'
#
# No rotation applied for 2dm-5844 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5844.
# Supercell expansion complete for 2dm-5844 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5844.xyz'
#
# No rotation applied for 2dm-5846 as z-components of a and b are zero.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5846.
# Supercell expansion complete for 2dm-5846 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5846.xyz'
#
# Rotation applied for 2dm-5847 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5847.
# Supercell expansion complete for 2dm-5847 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5847.xyz'
#
# Rotation applied for 2dm-5848 to align lattice plane with xy-plane.
# Additional rotation applied around z-axis to align a along x-axis for 2dm-5848.
# Supercell expansion complete for 2dm-5848 and saved to 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10\supercell_2dm-5848.xyz'
#
# Supercell expansion for all materials is complete and saved in the 'Supercells/supercells_flatband_rotated_shifted_aligned_10x10' folder.

# %%
#Supercell viewer

from ase.io import read
from ase.visualize import view

# Specify the path to the supercell file you want to view
# Replace 'supercell_flatband/supercell_2dm-21.xyz' with the desired file
supercell_file = 'Supercells/supercells_flatband_1x1/supercell_2dm-22.xyz'

# Read the supercell structure
supercell = read(supercell_file)

# View the supercell structure
view(supercell)
